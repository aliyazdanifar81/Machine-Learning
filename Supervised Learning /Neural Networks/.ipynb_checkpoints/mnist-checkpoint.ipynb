# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
import pandas as pd
import tensorflow as tf
import numpy as np
import keras
import matplotlib.pyplot as plt

# %%
# load Data
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# %%
# Normalize data
x_train, x_test =  x_train/ 255, x_test/255

# %%
# generate validation data
x_test, x_val, y_test, y_val = train_test_split(x_test, y_test, random_state=42, test_size=0.2)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(10, activation='softmax'),
])

# %%
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
history = model.fit(x_train, y_train , epochs=15, validation_data=(x_val, y_val))
# Out:
# Epoch 1/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.7534 - loss: 0.7795 - val_accuracy: 0.9480 - val_loss: 0.1994
# Epoch 2/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9417 - loss: 0.2214 - val_accuracy: 0.9515 - val_loss: 0.1607
# Epoch 3/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9569 - loss: 0.1672 - val_accuracy: 0.9570 - val_loss: 0.1598
# Epoch 4/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9622 - loss: 0.1430 - val_accuracy: 0.9515 - val_loss: 0.1713
# Epoch 5/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9650 - loss: 0.1277 - val_accuracy: 0.9630 - val_loss: 0.1415
# Epoch 6/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9682 - loss: 0.1157 - val_accuracy: 0.9605 - val_loss: 0.1291
# Epoch 7/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9730 - loss: 0.0983 - val_accuracy: 0.9655 - val_loss: 0.1343
# Epoch 8/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9739 - loss: 0.0906 - val_accuracy: 0.9670 - val_loss: 0.1357
# Epoch 9/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9769 - loss: 0.0810 - val_accuracy: 0.9625 - val_loss: 0.1558
# Epoch 10/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9780 - loss: 0.0779 - val_accuracy: 0.9595 - val_loss: 0.1586
# Epoch 11/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9774 - loss: 0.0780 - val_accuracy: 0.9625 - val_loss: 0.1398
# Epoch 12/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9792 - loss: 0.0714 - val_accuracy: 0.9635 - val_loss: 0.1460
# Epoch 13/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9824 - loss: 0.0631 - val_accuracy: 0.9650 - val_loss: 0.1298
# Epoch 14/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9817 - loss: 0.0630 - val_accuracy: 0.9635 - val_loss: 0.1529
# Epoch 15/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9826 - loss: 0.0574 - val_accuracy: 0.9685 - val_loss: 0.1493

# %%
model.evaluate(x_test, y_test)
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9713 - loss: 0.1437
# [0.14643512666225433, 0.9713749885559082]

# %%
df = pd.DataFrame(history.history)

# %%
plt.plot(df['accuracy'], label='train acc')
plt.plot(df['val_accuracy'], label='val acc')
plt.title('train acc VS val acc')
plt.legend()
plt.plot(df['loss'], label='train loss')
plt.plot(df['val_loss'], label='val loss')
plt.title('train loss VS val loss')
plt.legend()
