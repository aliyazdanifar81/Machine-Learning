# %%
import pandas as pd

# %%
train = pd.read_csv("./../Dataset_custom/Titanic/train.csv")
test = pd.read_csv("./../Dataset_custom/Titanic/test.csv")

# %%
x_train = train.drop(["PassengerId", "Name"], axis=1)
y_train = train["Survived"]

# %%
x_train.head(10)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
# 5         0       3    male   NaN      0      0            330877   8.4583
# 6         0       1    male  54.0      0      0             17463  51.8625
# 7         0       3    male   2.0      3      1            349909  21.0750
# 8         1       3  female  27.0      0      2            347742  11.1333
# 9         1       2  female  14.0      1      0            237736  30.0708
#
#   Cabin Embarked
# 0   NaN        S
# 1   C85        C
# 2   NaN        S
# 3  C123        S
# 4   NaN        S
# 5   NaN        Q
# ...

# %%
mode = x_train.mode().iloc[0]
mode["Cabin"] = "B96"

# %%
x_train = x_train.fillna(mode)

# %%
x_train.head(6)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
# 5         0       3    male  24.0      0      0            330877   8.4583
#
#   Cabin Embarked
# 0   B96        S
# 1   C85        C
# 2   B96        S
# 3  C123        S
# 4   B96        S
# 5   B96        Q
