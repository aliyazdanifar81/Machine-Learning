# %%
import pandas as pd
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

# %%
data = pd.read_csv('./../Dataset_custom/Cardiovascular_Disease_Dataset.csv')

# %%
data.head()
# Out:
#    patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0     103368   53       1          2        171                0
# 1     119250   40       1          0         94              229
# 2     119372   49       1          2        133              142
# 3     132514   43       1          0        138              295
# 4     146211   31       1          1        199                0
#
#    fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                  0                1           147              0      5.3
# 1                  0                1           115              0      3.7
# 2                  0                0           202              1      5.0
# 3                  1                1           153              0      3.2
# 4                  0                2           136              0      5.3
#
#    slope  noofmajorvessels  target
# 0      3                 3       1
# 1      1                 1       0
# 2      1                 0       0
# 3      2                 2       1
# 4      3                 2       1

# %%
x = data.drop('target', axis = 1)
y = data['target']

# %%
# normalization 
x = StandardScaler().fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
model = svm.SVC()

# %%
model.fit(x_train, y_train)
# Out:
# SVC()

# %%
# accuracy 
print(f"train acc = {model.score(x_train, y_train)}\ntest acc = {model.score(x_test, y_test)}")
# Out:
# train acc = 0.9885714285714285
# test acc = 0.9733333333333334
